# %%
import pandas as pd

# %%
a = pd.read_excel("phe-229-data-tables.xlsx",sheet_name='Table S3.2')

# %%
a.sheet_names
# Out:
# ['Contents',
#  'Table S2.1',
#  'Table S2.2',
#  'Table S2.3',
#  'Table S2.4',
#  'Table S3.1',
#  'Table S3.2',
#  'Table S4.1',
#  'Table S4.2',
#  'Table S5.1',
#  'Table S5.2',
#  'Table S5.3',
#  'Table S6.1',
#  'Table S6.2']

# %%
a.columns
# Out:
# Index(['Table S3.2: Leading causes of death, by age group, 2015–2017',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
b = a[2:54]

# %%
b = b.drop(['Table S3.2: Leading causes of death, by age group, 2015–2017',
       'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
       'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
       'Unnamed: 11', 'Unnamed: 12'],axis = 1)

# %%
b.columns = ['Cause_of_Death','Number','Percent','Crude_Rate']

# %%
b
# Out:
#                                        Cause_of_Death   Number   Percent  \
# 2                                      Cause of death  Number   Per cent
# 3                                                 NaN      NaN       NaN
# 4   Certain conditions originating in the perinata...     2348      78.8
# 5   Other ill-defined causes (R00–R94, R96–R99, I4...      202       6.8
# 6   Sudden infant death syndrome (SIDS) (R95)     ...       82       2.8
# 7   Accidental threats to breathing (W75–W84)     ...       31         1
# 8   Influenza and pneumonia (J09–J18)             ...       29         1
# 9   Cardiomyopathy (I42)                          ...       21       0.7
# 10  Diseases of myoneural junction and muscle (G70...       21       0.7
# 11  Selected metabolic disorders excl. dehydration...       18       0.6
# 12  Other disorders of the nervous system (G90–G99...       17       0.6
# 13  Spinal muscular atrophy and related syndromes ...       17       0.6
# ...

# %%
c = b[2:28]

# %%
c = c.reset_index()

# %%
c=c.drop([21,22,23,24,25])

# %%
c = c.drop(['index'],axis = 1)

# %%
c['Age_Group'] = '0-1'

# %%
c['Cause_of_Death']
# Out:
# 0     Certain conditions originating in the perinata...
# 1     Other ill-defined causes (R00–R94, R96–R99, I4...
# 2     Sudden infant death syndrome (SIDS) (R95)     ...
# 3     Accidental threats to breathing (W75–W84)     ...
# 4     Influenza and pneumonia (J09–J18)             ...
# 5     Cardiomyopathy (I42)                          ...
# 6     Diseases of myoneural junction and muscle (G70...
# 7     Selected metabolic disorders excl. dehydration...
# 8     Other disorders of the nervous system (G90–G99...
# 9     Spinal muscular atrophy and related syndromes ...
# 10    Assault (X85–Y09)                             ...
# 11    Acute respiratory diseases excl. influenza and...
# 12    Meningitis (A39, G00–G03)                     ...
# 13    Septicaemia (A40–A41)                         ...
# 14    Other viral diseases excl. mumps (B25–B34 excl...
# 15    Land transport accidents (V01–V89)            ...
# 16    Benign neoplasms, in situ and uncertain behavi...
# ...

# %%
c.iloc[:,0]
# Out:
# 0     Certain conditions originating in the perinata...
# 1     Other ill-defined causes (R00–R94, R96–R99, I4...
# 2     Sudden infant death syndrome (SIDS) (R95)     ...
# 3     Accidental threats to breathing (W75–W84)     ...
# 4     Influenza and pneumonia (J09–J18)             ...
# 5     Cardiomyopathy (I42)                          ...
# 6     Diseases of myoneural junction and muscle (G70...
# 7     Selected metabolic disorders excl. dehydration...
# 8     Other disorders of the nervous system (G90–G99...
# 9     Spinal muscular atrophy and related syndromes ...
# 10    Assault (X85–Y09)                             ...
# 11    Acute respiratory diseases excl. influenza and...
# 12    Meningitis (A39, G00–G03)                     ...
# 13    Septicaemia (A40–A41)                         ...
# 14    Other viral diseases excl. mumps (B25–B34 excl...
# 15    Land transport accidents (V01–V89)            ...
# 16    Benign neoplasms, in situ and uncertain behavi...
# ...

# %%
import re

# %%
for i in range(c.shape[0]):
    c.iloc[i,0] = re.sub("\(.*?\)","",c.iloc[i,0])

# %%
c
# Out:
#                                        Cause_of_Death Number Percent  \
# 0   Certain conditions originating in the perinata...   2348    78.8
# 1   Other ill-defined causes                      ...    202     6.8
# 2   Sudden infant death syndrome                  ...     82     2.8
# 3   Accidental threats to breathing               ...     31       1
# 4   Influenza and pneumonia                       ...     29       1
# 5   Cardiomyopathy                                ...     21     0.7
# 6   Diseases of myoneural junction and muscle     ...     21     0.7
# 7   Selected metabolic disorders excl. dehydration...     18     0.6
# 8   Other disorders of the nervous system         ...     17     0.6
# 9   Spinal muscular atrophy and related syndromes ...     17     0.6
# 10  Assault                                       ...     14     0.5
# 11  Acute respiratory diseases excl. influenza and...     12     0.4
# 12  Meningitis                                    ...     12     0.4
# ...

# %%
sum(c['Percent'])
# Out:
# 97.1

# %%
d = b[30:]

# %%
d['Age_Group'] ='1-14'
# Out:
# D:\Programs\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
d[:-2]
# Out:
#                                        Cause_of_Death Number Percent  \
# 32  Land transport accidents (V01–V89)            ...    153    11.1
# 33  Certain conditions originating in the perinata...    118     8.6
# 34  Brain cancer (C71)                            ...    106     7.7
# 35  Accidental drowning and submersion (W65–W74)  ...     95     6.9
# 36  Leukaemia (C91–C95)                           ...     66     4.8
# 37  Other ill-defined causes (R00–R94, R96–R99, I4...     62     4.5
# 38  Selected metabolic disorders excl. dehydration...     58     4.2
# 39  Suicide (X60–X84)                             ...     53     3.8
# 40  Assault (X85–Y09)                             ...     50     3.6
# 41  Cerebral palsy and other paralytic syndromes (...     40     2.9
# 42  Influenza and pneumonia (J09–J18)             ...     36     2.6
# 43  Epilepsy and status epilepticus (G40, G41)    ...     32     2.3
# 44  Malignant neoplasms of thyroid and other endoc...     28       2
# ...

# %%
d = d.reset_index()
d = d.drop(['index'],axis = 1)

# %%
d = d[:-2]

# %%
for i in range(d.shape[0]):
    d.iloc[i,0] = re.sub("\(.*?\)","",d.iloc[i,0])

# %%
d
# Out:
#                                        Cause_of_Death Number Percent  \
# 0   Land transport accidents                      ...    153    11.1
# 1   Certain conditions originating in the perinata...    118     8.6
# 2   Brain cancer                                  ...    106     7.7
# 3   Accidental drowning and submersion            ...     95     6.9
# 4   Leukaemia                                     ...     66     4.8
# 5   Other ill-defined causes                      ...     62     4.5
# 6   Selected metabolic disorders excl. dehydration...     58     4.2
# 7   Suicide                                       ...     53     3.8
# 8   Assault                                       ...     50     3.6
# 9   Cerebral palsy and other paralytic syndromes  ...     40     2.9
# 10  Influenza and pneumonia                       ...     36     2.6
# 11  Epilepsy and status epilepticus               ...     32     2.3
# 12  Malignant neoplasms of thyroid and other endoc...     28       2
# ...

# %%
sum(d['Percent'])
# Out:
# 76.2

# %%
k = c.append(d)

# %%
c.shape
# Out:
# (21, 5)

# %%
d.shape
# Out:
# (20, 5)

# %%
k
# Out:
#                                        Cause_of_Death Number Percent  \
# 0   Certain conditions originating in the perinata...   2348    78.8
# 1   Other ill-defined causes                      ...    202     6.8
# 2   Sudden infant death syndrome                  ...     82     2.8
# 3   Accidental threats to breathing               ...     31       1
# 4   Influenza and pneumonia                       ...     29       1
# 5   Cardiomyopathy                                ...     21     0.7
# 6   Diseases of myoneural junction and muscle     ...     21     0.7
# 7   Selected metabolic disorders excl. dehydration...     18     0.6
# 8   Other disorders of the nervous system         ...     17     0.6
# 9   Spinal muscular atrophy and related syndromes ...     17     0.6
# 10  Assault                                       ...     14     0.5
# 11  Acute respiratory diseases excl. influenza and...     12     0.4
# 12  Meningitis                                    ...     12     0.4
# ...

# %%
c.to_csv("Top_Causes_of_Death_0_to_1_2017.csv",index=None)

# %%
d.to_csv("Top_Causes_of_Death_1_to_14_2017.csv",index=None)

# %%
k.to_csv("Top_Causes_of_Death_0_to_14_2017.csv",index=None)
