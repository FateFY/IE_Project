# %%
import pandas as pd

# %%
serv = pd.read_csv('child_care_version2.csv')

# %%
serv.head()
# Out:
#                                 Name              Address     Suburb State  \
# 0  Alexandra & District Kindergarten     15 Bayley Street  Alexandra   VIC
# 1                Alexandra Baby Care     13 Coster Street  Alexandra   VIC
# 2                Altona Kindergarten      89 Blyth Street     Altona   VIC
# 3         Somers Parade Kindergarten      4 Somers Parade     Altona   VIC
# 4              Seaholme Kindergarten  2 Parkside Crescent   Seaholme   VIC
#
#    Postcode   Latitude   Longitude         Phone         Fax  \
# 0      3714 -37.192252  145.708658    0357721387         NaN
# 1      3714 -37.193338  145.707901  03 5772 2155         NaN
# 2      3018 -37.867719  144.825797    0393982839  0394450346
# 3      3018 -37.870909  144.810426    0393981526  0394450346
# 4      3018 -37.865715  144.844204    0393981216  0394450346
#
#                                    Email  \
# 0  alexandra.kin@kindergarten.vic.gov.au
# 1          alexandrababycare@bigpond.com
# ...

# %%
serv.columns
# Out:
# Index(['Name', 'Address', 'Suburb', 'State', 'Postcode', 'Latitude',
#        'Longitude', 'Phone', 'Fax', 'Email', 'Places', 'Services',
#        'Long_Day_Care', 'After_School_Care', 'Before_School_Care',
#        'Vacation_Care', 'Monday_Start_Time', 'Monday_End_Time',
#        'Tuesday_Start_Time', 'Tuesday_End_Time', 'Wednesday_Start_Time',
#        'Wednesday_End_Time', 'Thursday_Start_Time', 'Thursday_End_Time',
#        'Friday_Start_Time', 'Friday_End_Time', 'Saturday_Start_Time',
#        'Saturday_End_Time', 'Sunday_Start_Time', 'Sunday_End_Time',
#        'Weekday_Opening_Hour'],
#       dtype='object')

# %%
serv = serv[['Name', 'Address', 'Suburb', 'State', 'Postcode', 'Latitude',
       'Longitude', 'Phone', 'Fax', 'Email', 'Places', 'Services',
       'Weekday_Opening_Hour',
       'Long_Day_Care', 'After_School_Care', 'Before_School_Care',
       'Vacation_Care', 'Monday_Start_Time', 'Monday_End_Time',
       'Tuesday_Start_Time', 'Tuesday_End_Time', 'Wednesday_Start_Time',
       'Wednesday_End_Time', 'Thursday_Start_Time', 'Thursday_End_Time',
       'Friday_Start_Time', 'Friday_End_Time', 'Saturday_Start_Time',
       'Saturday_End_Time', 'Sunday_Start_Time', 'Sunday_End_Time']]

# %%
serv.head()
# Out:
#                                 Name              Address     Suburb State  \
# 0  Alexandra & District Kindergarten     15 Bayley Street  Alexandra   VIC
# 1                Alexandra Baby Care     13 Coster Street  Alexandra   VIC
# 2                Altona Kindergarten      89 Blyth Street     Altona   VIC
# 3         Somers Parade Kindergarten      4 Somers Parade     Altona   VIC
# 4              Seaholme Kindergarten  2 Parkside Crescent   Seaholme   VIC
#
#    Postcode   Latitude   Longitude         Phone         Fax  \
# 0      3714 -37.192252  145.708658    0357721387         NaN
# 1      3714 -37.193338  145.707901  03 5772 2155         NaN
# 2      3018 -37.867719  144.825797    0393982839  0394450346
# 3      3018 -37.870909  144.810426    0393981526  0394450346
# 4      3018 -37.865715  144.844204    0393981216  0394450346
#
#                                    Email       ...        \
# 0  alexandra.kin@kindergarten.vic.gov.au       ...
# ...

# %%
serv.columns.get_loc('Long_Day_Care')
# Out:
# 13

# %%
for i in range(serv.shape[0]):
    if serv.iloc[i,15] == 'Yes':
        serv.iloc[i,15] = 1
    else:
        serv.iloc[i,15] = None
    if serv.iloc[i,16] == 'Yes':
        serv.iloc[i,16] = 1
    else:
        serv.iloc[i,16] = None

# %%
serv.to_csv('child_care_version3.csv',index=False)

# %%
serv = pd.read_csv('child_care_version3.csv')

# %%
for i in range(serv.shape[0]):
    serv.iloc[i,7] = str(serv.iloc[i,7])
    serv.iloc[i,8] = str(serv.iloc[i,8])

# %%
serv.head()
# Out:
#                                 Name              Address     Suburb State  \
# 0  Alexandra & District Kindergarten     15 Bayley Street  Alexandra   VIC
# 1                Alexandra Baby Care     13 Coster Street  Alexandra   VIC
# 2                Altona Kindergarten      89 Blyth Street     Altona   VIC
# 3         Somers Parade Kindergarten      4 Somers Parade     Altona   VIC
# 4              Seaholme Kindergarten  2 Parkside Crescent   Seaholme   VIC
#
#    Postcode   Latitude   Longitude         Phone         Fax  \
# 0      3714 -37.192252  145.708658    0357721387         NaN
# 1      3714 -37.193338  145.707901  03 5772 2155         NaN
# 2      3018 -37.867719  144.825797    0393982839  0394450346
# 3      3018 -37.870910  144.810426    0393981526  0394450346
# 4      3018 -37.865715  144.844204    0393981216  0394450346
#
#                                    Email       ...        \
# 0  alexandra.kin@kindergarten.vic.gov.au       ...
# ...
