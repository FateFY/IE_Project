# %%
import pandas as pd

# %%
a = pd.read_excel('Victorian Emergency Minimum Dataset (VEMD) Data Tables- 2017-18.xlsx',sheet_name="Table 6 ",index_col=2)

# %%
a.shape
# Out:
# (34, 7)

# %%
a
# Out:
#                                         Unnamed: 0  \
# NaN                                            NaN
# NaN                                            NaN
# NaN                                            NaN
# NaN                                            NaN
# NaN                                            NaN
# NaN                                            NaN
# NaN                                            NaN
# NaN                                            NaN
# NaN                                            NaN
# NaN                                            NaN
# Cause of injury                                NaN
# Struck by or collision with person             NaN
# Struck by or collision with object             NaN
# Fall                                           NaN
# Cutting piercing object                        NaN
# Transport related                              NaN
# Poisoning                                      NaN
# ...

# %%
b = a[11:20]

# %%
b.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
b = b.drop(['Unnamed: 0', 'Unnamed: 1'],axis=1)

# %%
b
# Out:
#                                        Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# Struck by or collision with person             23         29         23
# Struck by or collision with object              5         14         13
# Fall                                           15         21         17
# Cutting piercing object                        ≤3          4         ≤3
# Transport related                              ≤3         ≤3         ≤3
# Poisoning                                      ≤3         ≤3         ≤3
# Contact burn (hot object or substance)         ≤3          6          4
# Unspecified external cause                      5          5          9
# Other cause                                    20         19         23
#
#                                        Unnamed: 6 Unnamed: 7
# Struck by or collision with person             59         61
# Struck by or collision with object             27         22
# Fall                                           18         17
# ...

# %%
b.columns = ['2014','2015','2016','2017','2018']

# %%
b['2014'][3]
# Out:
# '≤3'

# %%
b.shape
# Out:
# (9, 5)

# %%
for i in b.columns:
    for j in range(b.shape[0]-1):
        b[i][j] = int(str(b[i][j]).replace('≤',''))

# %%
b
# Out:
#                                        2014 2015 2016 2017 2018
# Struck by or collision with person       23   29   23   59   61
# Struck by or collision with object        5   14   13   27   22
# Fall                                     15   21   17   18   17
# Cutting piercing object                   3    4    3    9   11
# Transport related                         3    3    3    6    3
# Poisoning                                 3    3    3    3    3
# Contact burn (hot object or substance)    3    6    4    5    3
# Unspecified external cause                5    5    9   16    8
# Other cause                              20   19   23   22   18

# %%
b.to_csv('Victoria_Emergency_Causes_Under17_14_18.csv')

# %%
b
# Out:
#    Year Struck by or collision with person Struck by or collision with object  \
# 0  2014                                 23                                  5
# 1  2015                                 29                                 14
# 2  2016                                 23                                 13
# 3  2017                                 59                                 27
# 4  2018                                 61                                 22
#
#   Fall Cutting piercing object Transport related Poisoning  \
# 0   15                       3                 3         3
# 1   21                       4                 3         3
# 2   17                       3                 3         3
# 3   18                       9                 6         3
# 4   17                      11                 3         3
#
#   Contact burn (hot object or substance) Unspecified external cause  \
# 0                                      3                          5
# ...

# %%
b['number'] = 0

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-22ad16893fab> in <module>()
# ----> 1 sum(b.loc[2])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
for i in range(b.shape[0]):
    b.iloc[i,-1] = b.iloc[i,1] + b.iloc[i,2] + b.iloc[i,3] +b.iloc[i,4]+b.iloc[i,5]+b.iloc[i,6]+b.iloc[i,7]+b.iloc[i,8]

# %%
b
# Out:
#    Year Struck by or collision with person Struck by or collision with object  \
# 0  2014                                 23                                  5
# 1  2015                                 29                                 14
# 2  2016                                 23                                 13
# 3  2017                                 59                                 27
# 4  2018                                 61                                 22
#
#   Fall Cutting piercing object Transport related Poisoning  \
# 0   15                       3                 3         3
# 1   21                       4                 3         3
# 2   17                       3                 3         3
# 3   18                       9                 6         3
# 4   17                      11                 3         3
#
#   Contact burn (hot object or substance) Unspecified external cause  \
# 0                                      3                          5
# ...

# %%
d = pd.concat([b.Year, b.number], axis=1)

# %%
d
# Out:
#    Year  number
# 0  2014      60
# 1  2015      85
# 2  2016      75
# 3  2017     143
# 4  2018     128

# %%
d.to_csv("Total_Preventable_Injury_Number_Victoria_2014_2017.csv",index=None)

# %%
b= b.transpose()

# %%
b = b.reset_index()

# %%
b = b.rename(columns = {'index':'Year'})

# %%
c = pd.melt(b,id_vars='Year')

# %%
c.to_csv('Victoria_ED_Causes_14_18_Melt.csv',index=None)

# %%
c
# Out:
#     Year                                variable value
# 0   2014      Struck by or collision with person    23
# 1   2015      Struck by or collision with person    29
# 2   2016      Struck by or collision with person    23
# 3   2017      Struck by or collision with person    59
# 4   2018      Struck by or collision with person    61
# 5   2014      Struck by or collision with object     5
# 6   2015      Struck by or collision with object    14
# 7   2016      Struck by or collision with object    13
# 8   2017      Struck by or collision with object    27
# 9   2018      Struck by or collision with object    22
# 10  2014                                    Fall    15
# 11  2015                                    Fall    21
# 12  2016                                    Fall    17
# 13  2017                                    Fall    18
# 14  2018                                    Fall    17
# 15  2014                 Cutting piercing object     3
# ...
