# %%
import pandas as pd

# %%
a = pd.ExcelFile("CCOPMM_2017_Supplementary_Tables_CA.xlsx")

# %%
a.sheet_names
# Out:
# ['Index',
#  'Figure 7.1 ',
#  'Figure 7.2 ',
#  'Table 7.1a ',
#  'Table 7.1b ',
#  'Table 7.1c ',
#  'Table 7.2 ',
#  'Table 7.3a',
#  'Table 7.3b',
#  'Figure 7.3 a',
#  'Figure 7.3b',
#  'Table 7.4',
#  'Table 7.5',
#  'Figure 7.4',
#  'Table 7.6',
#  'Figure 7.5',
#  'Table 7.7',
#  'Table 7.8a',
#  'Figure 7.6a',
#  'Table 7.8b',
#  'Figure 7.6b',
#  'Figure 7.6c',
#  'Table 7.9',
#  'Figure 7.7a',
#  'Figure 7.7b',
#  'Figure 7.7c',
#  'Table 7.10',
#  'Figure 7.8',
#  'Table 7.11',
#  'Table 7.12',
#  'Table 7.13',
#  'Table 7.14',
#  'Table 7.15',
#  'Table 7.16',
#  'Figure 7.9',
#  'Figure 7.10a',
#  'Figure 7.10b',
#  'Table 7.17a',
#  'Figure 7.11a',
#  'Table 7.17 b',
#  'Figure 7.11b',
#  'Table 7.18a',
#  'Figure 7.12 a',
#  'Table 7.18b',
#  'Figure 7.12 b',
#  'Table 7.19 a',
#  'Table 7.19 b',
#  'Table 7.20',
#  'Figure 7.13',
#  'Table 7.21',
#  'Figure 7.14',
#  'Figure 7.15',
#  'Table 7.22',
#  'Table 7.23',
#  'Table 7.24',
#  'Figure 7.16',
# ...

# %%
a = pd.read_excel('CCOPMM_2017_Supplementary_Tables_CA.xlsx',sheet_name='Figure 7.16')

# %%
a = a[29:31]

# %%
a.columns
# Out:
# Index(['Back to Index', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34'],
#       dtype='object')

# %%
a
# Out:
#     Back to Index          Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4  \
# 29            NaN                 NaN       1985       1986  1987.000000
# 30            NaN  28 days - 14 years    11.0551    9.49757    10.756158
#
#      Unnamed: 5   Unnamed: 6  Unnamed: 7   Unnamed: 8   Unnamed: 9  \
# 29  1988.000000  1989.000000  1990.00000  1991.000000  1992.000000
# 30     9.585146    10.528204     9.06894     9.558128     7.302994
#
#        ...       Unnamed: 25  Unnamed: 26  Unnamed: 27  Unnamed: 28  \
# 29     ...       2008.000000  2009.000000  2010.000000  2011.000000
# 30     ...          2.339481     5.126097     3.084592     2.956434
#
#     Unnamed: 29  Unnamed: 30  Unnamed: 31  Unnamed: 32  Unnamed: 33  \
# 29  2012.000000  2013.000000   2014.00000  2015.000000  2016.000000
# 30     2.220283     2.169494      2.58432     1.173548     1.666573
#
#     Unnamed: 34
# 29  2017.000000
# 30     1.200169
#
# [2 rows x 35 columns]

# %%
a = a.drop(['Back to Index', 'Unnamed: 1'],axis = 1)

# %%
year = 1985
for i in range(a.shape[1]):
    
    a.iloc[0,i] = year
    year+=1

# %%
a
# Out:
#    Unnamed: 2 Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  Unnamed: 7  \
# 29       1985       1986  1987.000000  1988.000000  1989.000000  1990.00000
# 30    11.0551    9.49757    10.756158     9.585146    10.528204     9.06894
#
#      Unnamed: 8   Unnamed: 9  Unnamed: 10  Unnamed: 11     ...       \
# 29  1991.000000  1992.000000  1993.000000  1994.000000     ...
# 30     9.558128     7.302994     6.465727     4.142163     ...
#
#     Unnamed: 25  Unnamed: 26  Unnamed: 27  Unnamed: 28  Unnamed: 29  \
# 29  2008.000000  2009.000000  2010.000000  2011.000000  2012.000000
# 30     2.339481     5.126097     3.084592     2.956434     2.220283
#
#     Unnamed: 30  Unnamed: 31  Unnamed: 32  Unnamed: 33  Unnamed: 34
# 29  2013.000000   2014.00000  2015.000000  2016.000000  2017.000000
# 30     2.169494      2.58432     1.173548     1.666573     1.200169
#
# [2 rows x 33 columns]

# %%
a = a.transpose()

# %%
a.columns = ['Year','Death_Rate']

# %%
a.to_csv("Unintentional_Death_Rate_0_14_85_17.csv",index= None)

# %%
b = pd.read_excel('CCOPMM_2017_Supplementary_Tables_CA.xlsx',sheet_name='Figure 7.17 a')

# %%
b = b[29:37]

# %%
b
# Out:
#     Back to Index               Unnamed: 1 Unnamed: 2   Unnamed: 3  \
# 29            NaN                      NaN       1985  1986.000000
# 30            NaN  Motor vehicle accidents    7.26475     6.509569
# 31            NaN                 Drowning    2.10572     1.493999
# 32            NaN                     Fire   0.631717     0.320143
# 33            NaN             Asphyxiation   0.421145     0.533571
# 34            NaN          Train accidents   0.210572     0.106714
# 35            NaN                    Other   0.421145     0.533571
# 36            NaN                    Total    11.0551     9.497568
#
#      Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7   Unnamed: 8  \
# 29  1987.000000  1988.000000  1989.000000  1990.000000  1991.000000
# 30     6.131010     5.492612     5.693825     4.587817     4.566661
# 31     2.581478     1.938569     2.685766     2.560642     2.336431
# 32     0.537808     0.430793     0.859445     0.106693     0.743410
# ...

# %%
b = b.drop(['Back to Index'],axis = 1)

# %%
b
# Out:
#                  Unnamed: 1 Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5  \
# 29                      NaN       1985  1986.000000  1987.000000  1988.000000
# 30  Motor vehicle accidents    7.26475     6.509569     6.131010     5.492612
# 31                 Drowning    2.10572     1.493999     2.581478     1.938569
# 32                     Fire   0.631717     0.320143     0.537808     0.430793
# 33             Asphyxiation   0.421145     0.533571     0.537808     0.323095
# 34          Train accidents   0.210572     0.106714     0.000000     0.538491
# 35                    Other   0.421145     0.533571     0.968054     0.861586
# 36                    Total    11.0551     9.497568    10.756158     9.585146
#
#      Unnamed: 6   Unnamed: 7   Unnamed: 8   Unnamed: 9  Unnamed: 10  \
# 29  1989.000000  1990.000000  1991.000000  1992.000000  1993.000000
# 30     5.693825     4.587817     4.566661     3.386896     3.179866
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, Unnamed: 2 to Unnamed: 34
# Data columns (total 8 columns):
# Year                       33 non-null object
# Motor_Vehicle_Accidents    33 non-null object
# Drowning                   33 non-null object
# Fire                       33 non-null object
# Asphyxiation               33 non-null object
# Train_Accidents            33 non-null object
# Other                      33 non-null object
# Total                      33 non-null object
# dtypes: object(8)
# memory usage: 2.3+ KB

# %%
b.describe()
# Out:
#           Year  Motor_Vehicle_Accidents   Drowning  Fire  Asphyxiation  \
# count     33.0                33.000000  33.000000  33.0     33.000000
# unique    33.0                33.000000  33.000000  29.0     33.000000
# top     2017.0                 1.476754   2.228405   0.0      0.208686
# freq       1.0                 1.000000   1.000000   5.0      1.000000
#
#         Train_Accidents      Other      Total
# count              33.0  33.000000  33.000000
# unique             19.0  33.000000  33.000000
# top                 0.0   0.211681   2.220283
# freq               15.0   1.000000   1.000000

# %%
b = b.transpose()

# %%
b.columns = ['Year','Motor_Vehicle_Accidents','Drowning','Fire','Asphyxiation','Train_Accidents','Other','Total']

# %%
b = b[1:]

# %%
b1 = pd.melt(b,id_vars='Year')

# %%
b1
# Out:
#      Year                 variable     value
# 0    1985  Motor_Vehicle_Accidents   7.26475
# 1    1986  Motor_Vehicle_Accidents   6.50957
# 2    1987  Motor_Vehicle_Accidents   6.13101
# 3    1988  Motor_Vehicle_Accidents   5.49261
# 4    1989  Motor_Vehicle_Accidents   5.69382
# 5    1990  Motor_Vehicle_Accidents   4.58782
# 6    1991  Motor_Vehicle_Accidents   4.56666
# 7    1992  Motor_Vehicle_Accidents    3.3869
# 8    1993  Motor_Vehicle_Accidents   3.17987
# 9    1994  Motor_Vehicle_Accidents   1.48693
# 10   1995  Motor_Vehicle_Accidents   3.60789
# 11   1996  Motor_Vehicle_Accidents   3.50143
# 12   1997  Motor_Vehicle_Accidents   2.43856
# 13   1998  Motor_Vehicle_Accidents   2.96353
# 14   1999  Motor_Vehicle_Accidents   2.21766
# 15   2000  Motor_Vehicle_Accidents   2.10575
# 16   2001  Motor_Vehicle_Accidents   1.78416
# 17   2002  Motor_Vehicle_Accidents   2.61825
# 18   2003  Motor_Vehicle_Accidents   2.51151
# 19   2004  Motor_Vehicle_Accidents    1.4634
# ...

# %%
b.to_csv('Unintentive_Death_Causes_85_17_Trans.csv',index = None)

# %%
b1.to_csv('Unintentive_Death_Causes_85_17_Melt.csv',index = None)

# %%
c = pd.read_csv('1.csv')

# %%
c.head()
# Out:
#       Unnamed: 0   1985   1986   1987   1988   1989   1990   1991   1992  \
# 0  28 - 364 days  334.4  336.3  326.6  312.4  328.0  275.0  197.5  191.0
# 1    1 - 4 years   44.7   36.5   37.9   41.2   35.8   33.8   30.3   34.6
#
#     1993  ...    2008  2009   2010  2011  2012  2013  2014  2015  2016  2017
# 0  172.5  ...   120.7  91.0  129.9  85.6  89.6  87.2  93.9  79.6  91.0  86.5
# 1   37.0  ...    17.9  18.4   17.6  17.4  19.1  11.1  14.8  15.4  12.5  11.0
#
# [2 rows x 34 columns]

# %%
c.loc[2] = 0

# %%
for i in range(c.shape[1]):
    if i !=0:
        c.iloc[2,i]=round((c.iloc[0,i]+c.iloc[1,i]),2)

# %%
c.iloc[2,0] = '0 - 4 years'

# %%
c
# Out:
#       Unnamed: 0   1985   1986   1987   1988   1989   1990   1991   1992  \
# 0  28 - 364 days  334.4  336.3  326.6  312.4  328.0  275.0  197.5  191.0
# 1    1 - 4 years   44.7   36.5   37.9   41.2   35.8   33.8   30.3   34.6
# 2    0 - 4 years  379.1  372.8  364.5  353.6  363.8  308.8  227.8  225.6
#
#     1993  ...    2008   2009   2010   2011   2012  2013   2014  2015   2016  \
# 0  172.5  ...   120.7   91.0  129.9   85.6   89.6  87.2   93.9  79.6   91.0
# 1   37.0  ...    17.9   18.4   17.6   17.4   19.1  11.1   14.8  15.4   12.5
# 2  209.5  ...   138.6  109.4  147.5  103.0  108.7  98.3  108.7  95.0  103.5
#
#    2017
# 0  86.5
# 1  11.0
# 2  97.5
#
# [3 rows x 34 columns]

# %%
round(c['1985'].sum(),2)
# Out:
# 379.1

# %%
d = pd.melt(c,id_vars='Unnamed: 0')

# %%
d.columns = ['Age','Year','Death_Rate']

# %%
d
# Out:
#               Age  Year  Death_Rate
# 0   28 - 364 days  1985       334.4
# 1     1 - 4 years  1985        44.7
# 2     0 - 4 years  1985       379.1
# 3   28 - 364 days  1986       336.3
# 4     1 - 4 years  1986        36.5
# 5     0 - 4 years  1986       372.8
# 6   28 - 364 days  1987       326.6
# 7     1 - 4 years  1987        37.9
# 8     0 - 4 years  1987       364.5
# 9   28 - 364 days  1988       312.4
# 10    1 - 4 years  1988        41.2
# 11    0 - 4 years  1988       353.6
# 12  28 - 364 days  1989       328.0
# 13    1 - 4 years  1989        35.8
# 14    0 - 4 years  1989       363.8
# 15  28 - 364 days  1990       275.0
# 16    1 - 4 years  1990        33.8
# 17    0 - 4 years  1990       308.8
# 18  28 - 364 days  1991       197.5
# 19    1 - 4 years  1991        30.3
# 20    0 - 4 years  1991       227.8
# 21  28 - 364 days  1992       191.0
# 22    1 - 4 years  1992        34.6
# 23    0 - 4 years  1992       225.6
# 24  28 - 364 days  1993       172.5
# ...

# %%
d.to_csv("Death_Rate_Victoria_85_17_by_Age.csv",index=None)

# %%
e = d[d['Age']=='0 - 4 years']

# %%
e = e.drop(['Age'],axis=1)

# %%
e.to_csv("Death_Rate_Victoria_85_17_0_4.csv",index=None)
