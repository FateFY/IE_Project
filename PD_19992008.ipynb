# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
a = pd.ExcelFile('1999-2008.xlsx')
a.sheet_names
# Out:
# ['Drown', 'Burn', 'Poison', 'Choke', 'Fall', 'Crush', 'Transport', 'Electric']

# %% [markdown]
# ### Drown

# %%
drown = pd.read_excel('1999-2008.xlsx',sheet_name='Drown')
drown.columns
# Out:
# Index(['Age', 'Sex', 'Year', 'Value'], dtype='object')

# %%
for i in ['0-1','1-4']:
    for j in range(1999,2009):
        l1 = [[i,'Persons', j,drown.Value[(drown['Age'] == i) & (drown['Year'] == j)].sum()]]
        l1 = pd.DataFrame(l1,columns=['Age','Sex','Year','Value'])
        print(l1)
        drown = drown.append(l1)
        
for i in ['Male','Female']:
    for j in range(1999,2009):
        l2 = [['0-4',i, j,drown.Value[(drown['Sex'] == i) & (drown['Year'] == j)].sum()]]
        l2 = pd.DataFrame(l2,columns=['Age','Sex','Year','Value'])
        print(l2)
        drown = drown.append(l2)
        
for i in range(1999,2009):
    l3 = [['0-4','Persons',i,drown.Value[(drown['Sex']=='Persons') & (drown['Year']==i)].sum()]]
    l3 = pd.DataFrame(l3,columns=['Age','Sex','Year','Value'])
    print(l3)
    drown = drown.append(l3)
# Out:
#    Age      Sex  Year  Value
# 0  0-1  Persons  1999     49
#    Age      Sex  Year  Value
# 0  0-1  Persons  2000     43
#    Age      Sex  Year  Value
# 0  0-1  Persons  2001     48
#    Age      Sex  Year  Value
# 0  0-1  Persons  2002     51
#    Age      Sex  Year  Value
# 0  0-1  Persons  2003     33
#    Age      Sex  Year  Value
# 0  0-1  Persons  2004     35
#    Age      Sex  Year  Value
# 0  0-1  Persons  2005     31
#    Age      Sex  Year  Value
# 0  0-1  Persons  2006     37
#    Age      Sex  Year  Value
# 0  0-1  Persons  2007     30
#    Age      Sex  Year  Value
# 0  0-1  Persons  2008     29
#    Age      Sex  Year  Value
# 0  1-4  Persons  1999    242
#    Age      Sex  Year  Value
# 0  1-4  Persons  2000    261
#    Age      Sex  Year  Value
# 0  1-4  Persons  2001    256
#    Age      Sex  Year  Value
# 0  1-4  Persons  2002    239
#    Age      Sex  Year  Value
# 0  1-4  Persons  2003    202
#    Age      Sex  Year  Value
# 0  1-4  Persons  2004    230
# ...

# %%
drown['Type'] = 'Drown'
drown
# Out:
#     Age      Sex  Year  Value   Type
# 0   0-1     Male  1999     29  Drown
# 1   0-1     Male  2000     29  Drown
# 2   0-1     Male  2001     26  Drown
# 3   0-1     Male  2002     29  Drown
# 4   0-1     Male  2003     23  Drown
# 5   0-1     Male  2004     14  Drown
# 6   0-1     Male  2005     14  Drown
# 7   0-1     Male  2006     22  Drown
# 8   0-1     Male  2007     21  Drown
# 9   0-1     Male  2008     22  Drown
# 10  0-1   Female  1999     20  Drown
# 11  0-1   Female  2000     14  Drown
# 12  0-1   Female  2001     22  Drown
# 13  0-1   Female  2002     22  Drown
# 14  0-1   Female  2003     10  Drown
# 15  0-1   Female  2004     21  Drown
# 16  0-1   Female  2005     17  Drown
# 17  0-1   Female  2006     15  Drown
# 18  0-1   Female  2007      9  Drown
# 19  0-1   Female  2008      7  Drown
# 20  1-4     Male  1999    167  Drown
# 21  1-4     Male  2000    159  Drown
# 22  1-4     Male  2001    163  Drown
# 23  1-4     Male  2002    149  Drown
# ...

# %%
drown.shape
# Out:
# (90, 5)

# %% [markdown]
# ### Burn

# %%
burn = pd.read_excel('1999-2008.xlsx',sheet_name='Burn')
burn.columns
# Out:
# Index(['Age', 'Sex', 'Year', 'Value', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6'],
#       dtype='object')

# %%
burn = burn.drop(['Unnamed: 4', 'Unnamed: 5',
       'Unnamed: 6'],axis=1)

# %%
for i in ['0-1','1-4']:
    for j in range(1999,2009):
        l1 = [[i,'Persons', j,burn.Value[(burn['Age'] == i) & (burn['Year'] == j)].sum()]]
        l1 = pd.DataFrame(l1,columns=['Age','Sex','Year','Value'])
        print(l1)
        burn = burn.append(l1)

for i in ['Male','Female']:
    for j in range(1999,2009):
        l2 = [['0-4',i, j,burn.Value[(burn['Sex'] == i) & (burn['Year'] == j)].sum()]]
        l2 = pd.DataFrame(l2,columns=['Age','Sex','Year','Value'])
        print(l2)
        burn = burn.append(l2)
        
for i in range(1999,2009):
    l3 = [['0-4','Persons',i,burn.Value[(burn['Sex']=='Persons') & (burn['Year']==i)].sum()]]
    l3 = pd.DataFrame(l3,columns=['Age','Sex','Year','Value'])
    print(l3)
    burn = burn.append(l3)
# Out:
#    Age      Sex  Year  Value
# 0  0-1  Persons  1999    313
#    Age      Sex  Year  Value
# 0  0-1  Persons  2000    318
#    Age      Sex  Year  Value
# 0  0-1  Persons  2001    285
#    Age      Sex  Year  Value
# 0  0-1  Persons  2002    299
#    Age      Sex  Year  Value
# 0  0-1  Persons  2003    277
#    Age      Sex  Year  Value
# 0  0-1  Persons  2004    290
#    Age      Sex  Year  Value
# 0  0-1  Persons  2005    311
#    Age      Sex  Year  Value
# 0  0-1  Persons  2006    319
#    Age      Sex  Year  Value
# 0  0-1  Persons  2007    267
#    Age      Sex  Year  Value
# 0  0-1  Persons  2008    343
#    Age      Sex  Year  Value
# 0  1-4  Persons  1999   1528
#    Age      Sex  Year  Value
# 0  1-4  Persons  2000   1420
#    Age      Sex  Year  Value
# 0  1-4  Persons  2001   1426
#    Age      Sex  Year  Value
# 0  1-4  Persons  2002   1534
#    Age      Sex  Year  Value
# 0  1-4  Persons  2003   1457
#    Age      Sex  Year  Value
# 0  1-4  Persons  2004   1449
# ...

# %%
burn['Type'] = 'Burn'
burn.head()
# Out:
#     Age      Sex  Year  Value  Type
# 0   0-1     Male  1999    179  Burn
# 1   0-1     Male  2000    189  Burn
# 2   0-1     Male  2001    166  Burn
# 3   0-1     Male  2002    174  Burn
# 4   0-1     Male  2003    163  Burn
# 5   0-1     Male  2004    172  Burn
# 6   0-1     Male  2005    183  Burn
# 7   0-1     Male  2006    171  Burn
# 8   0-1     Male  2007    162  Burn
# 9   0-1     Male  2008    203  Burn
# 10  0-1   Female  1999    134  Burn
# 11  0-1   Female  2000    129  Burn
# 12  0-1   Female  2001    119  Burn
# 13  0-1   Female  2002    125  Burn
# 14  0-1   Female  2003    114  Burn
# 15  0-1   Female  2004    118  Burn
# 16  0-1   Female  2005    128  Burn
# 17  0-1   Female  2006    148  Burn
# 18  0-1   Female  2007    105  Burn
# 19  0-1   Female  2008    140  Burn
# 20  1-4     Male  1999    862  Burn
# 21  1-4     Male  2000    855  Burn
# 22  1-4     Male  2001    846  Burn
# 23  1-4     Male  2002    900  Burn
# 24  1-4     Male  2003    894  Burn
# ...

# %% [markdown]
# ### Poison

# %%
poison = pd.read_excel('1999-2008.xlsx',sheet_name='Poison')
poison.columns
# Out:
# Index(['Age', 'Sex', 'Year', 'Value', 'Unnamed: 4', 'Unnamed: 5'], dtype='object')

# %%
poison = poison.drop(['Unnamed: 4', 'Unnamed: 5'],axis=1)

# %%
for i in ['0-1','1-4']:
    for j in range(1999,2009):
        l1 = [[i,'Persons', j,poison.Value[(poison['Age'] == i) & (poison['Year'] == j)].sum()]]
        l1 = pd.DataFrame(l1,columns=['Age','Sex','Year','Value'])
        poison = poison.append(l1)

for i in ['Male','Female']:
    for j in range(1999,2009):
        l2 = [['0-4',i, j,poison.Value[(poison['Sex'] == i) & (poison['Year'] == j)].sum()]]
        l2 = pd.DataFrame(l2,columns=['Age','Sex','Year','Value'])
        poison = poison.append(l2)
        
for i in range(1999,2009):
    l3 = [['0-4','Persons',i,poison.Value[(poison['Sex']=='Persons') & (poison['Year']==i)].sum()]]
    l3 = pd.DataFrame(l3,columns=['Age','Sex','Year','Value'])
    poison = poison.append(l3)

# %%
poison['Type'] = 'Poison'
poison.head()
# Out:
#     Age      Sex  Year  Value    Type
# 0   0-1     Male  1999    162  Poison
# 1   0-1     Male  2000    149  Poison
# 2   0-1     Male  2001    121  Poison
# 3   0-1     Male  2002    111  Poison
# 4   0-1     Male  2003    109  Poison
# 5   0-1     Male  2004     84  Poison
# 6   0-1     Male  2005     90  Poison
# 7   0-1     Male  2006     68  Poison
# 8   0-1     Male  2007     70  Poison
# 9   0-1     Male  2008     49  Poison
# 10  0-1   Female  1999    117  Poison
# 11  0-1   Female  2000    130  Poison
# 12  0-1   Female  2001     98  Poison
# 13  0-1   Female  2002     99  Poison
# 14  0-1   Female  2003     95  Poison
# 15  0-1   Female  2004     87  Poison
# 16  0-1   Female  2005     75  Poison
# 17  0-1   Female  2006     51  Poison
# 18  0-1   Female  2007     57  Poison
# 19  0-1   Female  2008     69  Poison
# 20  1-4     Male  1999   1781  Poison
# 21  1-4     Male  2000   1715  Poison
# 22  1-4     Male  2001   1614  Poison
# 23  1-4     Male  2002   1552  Poison
# ...

# %% [markdown]
# ### Choke

# %%
choke = pd.read_excel('1999-2008.xlsx',sheet_name='Choke')
choke.columns
# Out:
# Index(['Age', 'Sex', 'Year', 'Value'], dtype='object')

# %%
for i in ['0-1','1-4']:
    for j in range(1999,2009):
        l1 = [[i,'Persons', j,choke.Value[(choke['Age'] == i) & (choke['Year'] == j)].sum()]]
        l1 = pd.DataFrame(l1,columns=['Age','Sex','Year','Value'])
        choke = choke.append(l1)

for i in ['Male','Female']:
    for j in range(1999,2009):
        l2 = [['0-4',i, j,choke.Value[(choke['Sex'] == i) & (choke['Year'] == j)].sum()]]
        l2 = pd.DataFrame(l2,columns=['Age','Sex','Year','Value'])
        choke = choke.append(l2)
        
for i in range(1999,2009):
    l3 = [['0-4','Persons',i,choke.Value[(choke['Sex']=='Persons') & (choke['Year']==i)].sum()]]
    l3 = pd.DataFrame(l3,columns=['Age','Sex','Year','Value'])
    choke = choke.append(l3)

# %%
choke['Type'] = 'Choke'
choke
# Out:
#     Age      Sex  Year  Value   Type
# 0   0-1     Male  1999      5  Choke
# 1   0-1     Male  2000      7  Choke
# 2   0-1     Male  2001      6  Choke
# 3   0-1     Male  2002      3  Choke
# 4   0-1     Male  2003      3  Choke
# 5   0-1     Male  2004     11  Choke
# 6   0-1     Male  2005     13  Choke
# 7   0-1     Male  2006      5  Choke
# 8   0-1     Male  2007      3  Choke
# 9   0-1     Male  2008      1  Choke
# 10  0-1   Female  1999      3  Choke
# 11  0-1   Female  2000      1  Choke
# 12  0-1   Female  2001      9  Choke
# 13  0-1   Female  2002      2  Choke
# 14  0-1   Female  2003      2  Choke
# 15  0-1   Female  2004      2  Choke
# 16  0-1   Female  2005      2  Choke
# 17  0-1   Female  2006      5  Choke
# 18  0-1   Female  2007      5  Choke
# 19  0-1   Female  2008      0  Choke
# 20  1-4     Male  1999      5  Choke
# 21  1-4     Male  2000      5  Choke
# 22  1-4     Male  2001      7  Choke
# 23  1-4     Male  2002     10  Choke
# ...

# %% [markdown]
# ### Fall

# %%
fall = pd.read_excel('1999-2008.xlsx',sheet_name='Fall')
fall.columns
# Out:
# Index(['Age', 'Sex', 'Year', 'Value', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16'],
#       dtype='object')

# %%
fall = fall.drop(['Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
       'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
       'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
       'Unnamed: 16'],axis=1)

# %%
for i in ['0-1','1-4']:
    for j in range(1999,2009):
        l1 = [[i,'Persons', j,fall.Value[(fall['Age'] == i) & (fall['Year'] == j)].sum()]]
        l1 = pd.DataFrame(l1,columns=['Age','Sex','Year','Value'])
        fall = fall.append(l1)

for i in ['Male','Female']:
    for j in range(1999,2009):
        l2 = [['0-4',i, j,fall.Value[(fall['Sex'] == i) & (fall['Year'] == j)].sum()]]
        l2 = pd.DataFrame(l2,columns=['Age','Sex','Year','Value'])
        fall = fall.append(l2)
        
for i in range(1999,2009):
    l3 = [['0-4','Persons',i,fall.Value[(fall['Sex']=='Persons') & (fall['Year']==i)].sum()]]
    l3 = pd.DataFrame(l3,columns=['Age','Sex','Year','Value'])
    fall = fall.append(l3)

# %%
fall['Type'] ='Fall'
fall
# Out:
#     Age      Sex  Year  Value  Type
# 0   0-1     Male  1999    798  Fall
# 1   0-1     Male  2000    767  Fall
# 2   0-1     Male  2001    733  Fall
# 3   0-1     Male  2002    725  Fall
# 4   0-1     Male  2003    792  Fall
# 5   0-1     Male  2004    752  Fall
# 6   0-1     Male  2005    719  Fall
# 7   0-1     Male  2006    901  Fall
# 8   0-1     Male  2007    838  Fall
# 9   0-1     Male  2008    891  Fall
# 10  0-1   Female  1999    692  Fall
# 11  0-1   Female  2000    679  Fall
# 12  0-1   Female  2001    604  Fall
# 13  0-1   Female  2002    625  Fall
# 14  0-1   Female  2003    660  Fall
# 15  0-1   Female  2004    619  Fall
# 16  0-1   Female  2005    691  Fall
# 17  0-1   Female  2006    678  Fall
# 18  0-1   Female  2007    725  Fall
# 19  0-1   Female  2008    718  Fall
# 20  1-4     Male  1999   7486  Fall
# 21  1-4     Male  2000   7525  Fall
# 22  1-4     Male  2001   7417  Fall
# 23  1-4     Male  2002   7453  Fall
# 24  1-4     Male  2003   7401  Fall
# ...

# %% [markdown]
# ### Crush

# %%
crush = pd.read_excel('1999-2008.xlsx',sheet_name='Crush')
crush.columns
# Out:
# Index(['Age', 'Sex', 'Year', 'Value', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')

# %%
crush = crush.drop(['Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
       'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
       'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
       'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
       'Unnamed: 20', 'Unnamed: 21'],axis=1)

# %%
for i in ['0-1','1-4']:
    for j in range(1999,2009):
        l1 = [[i,'Persons', j,crush.Value[(crush['Age'] == i) & (crush['Year'] == j)].sum()]]
        l1 = pd.DataFrame(l1,columns=['Age','Sex','Year','Value'])
        crush = crush.append(l1)

for i in ['Male','Female']:
    for j in range(1999,2009):
        l2 = [['0-4',i, j,crush.Value[(crush['Sex'] == i) & (crush['Year'] == j)].sum()]]
        l2 = pd.DataFrame(l2,columns=['Age','Sex','Year','Value'])
        crush = crush.append(l2)
        
for i in range(1999,2009):
    l3 = [['0-4','Persons',i,crush.Value[(crush['Sex']=='Persons') & (crush['Year']==i)].sum()]]
    l3 = pd.DataFrame(l3,columns=['Age','Sex','Year','Value'])
    crush = crush.append(l3)

# %%
crush['Type'] = 'Crush'
crush
# Out:
#     Age      Sex  Year  Value   Type
# 0   0-1     Male  1999      6  Crush
# 1   0-1     Male  2000      4  Crush
# 2   0-1     Male  2001      5  Crush
# 3   0-1     Male  2002      3  Crush
# 4   0-1     Male  2003      4  Crush
# 5   0-1     Male  2004      1  Crush
# 6   0-1     Male  2005      3  Crush
# 7   0-1     Male  2006      3  Crush
# 8   0-1     Male  2007      3  Crush
# 9   0-1     Male  2008      2  Crush
# 10  0-1   Female  1999      1  Crush
# 11  0-1   Female  2000      1  Crush
# 12  0-1   Female  2001      1  Crush
# 13  0-1   Female  2002      3  Crush
# 14  0-1   Female  2003      2  Crush
# 15  0-1   Female  2004      2  Crush
# 16  0-1   Female  2005      1  Crush
# 17  0-1   Female  2006      2  Crush
# 18  0-1   Female  2007      0  Crush
# 19  0-1   Female  2008      3  Crush
# 20  1-4     Male  1999     74  Crush
# 21  1-4     Male  2000     63  Crush
# 22  1-4     Male  2001     64  Crush
# 23  1-4     Male  2002     69  Crush
# ...

# %% [markdown]
# ### Transport

# %%
trans = pd.read_excel('1999-2008.xlsx',sheet_name='Transport')
trans.columns
# Out:
# Index(['Age', 'Sex', 'Year', 'Value'], dtype='object')

# %%
for i in ['0-1','1-4']:
    for j in range(1999,2009):
        l1 = [[i,'Persons', j,trans.Value[(trans['Age'] == i) & (trans['Year'] == j)].sum()]]
        l1 = pd.DataFrame(l1,columns=['Age','Sex','Year','Value'])
        trans = trans.append(l1)

for i in ['Male','Female']:
    for j in range(1999,2009):
        l2 = [['0-4',i, j,trans.Value[(trans['Sex'] == i) & (trans['Year'] == j)].sum()]]
        l2 = pd.DataFrame(l2,columns=['Age','Sex','Year','Value'])
        trans = trans.append(l2)
        
for i in range(1999,2009):
    l3 = [['0-4','Persons',i,trans.Value[(trans['Sex']=='Persons') & (trans['Year']==i)].sum()]]
    l3 = pd.DataFrame(l3,columns=['Age','Sex','Year','Value'])
    trans = trans.append(l3)
    
trans['Type'] = 'Transport'

# %% [markdown]
# ### Electric

# %%
elec = pd.read_excel('1999-2008.xlsx',sheet_name='Electric')
elec.columns
# Out:
# Index(['Age', 'Sex', 'Year', 'Value'], dtype='object')

# %%
for i in ['0-1','1-4']:
    for j in range(1999,2009):
        l1 = [[i,'Persons', j,elec.Value[(elec['Age'] == i) & (elec['Year'] == j)].sum()]]
        l1 = pd.DataFrame(l1,columns=['Age','Sex','Year','Value'])
        elec = elec.append(l1)

for i in ['Male','Female']:
    for j in range(1999,2009):
        l2 = [['0-4',i, j,elec.Value[(elec['Sex'] == i) & (elec['Year'] == j)].sum()]]
        l2 = pd.DataFrame(l2,columns=['Age','Sex','Year','Value'])
        elec = elec.append(l2)
        
for i in range(1999,2009):
    l3 = [['0-4','Persons',i,elec.Value[(elec['Sex']=='Persons') & (elec['Year']==i)].sum()]]
    l3 = pd.DataFrame(l3,columns=['Age','Sex','Year','Value'])
    elec = elec.append(l3)
    
elec['Type'] = 'Electric'

# %% [markdown]
# ### Combine

# %%
b = drown.append(burn).append(poison).append(choke).append(fall).append(crush).append(trans).append(elec)

# %%
b.head()
# Out:
#    Age   Sex  Year  Value   Type
# 0  0-1  Male  1999     29  Drown
# 1  0-1  Male  2000     29  Drown
# 2  0-1  Male  2001     26  Drown
# 3  0-1  Male  2002     29  Drown
# 4  0-1  Male  2003     23  Drown

# %%
b[b.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, Year, Value, Type]
# Index: []

# %%
b[b.Sex == 1999]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, Year, Value, Type]
# Index: []

# %%
b.shape
# Out:
# (720, 5)

# %%
b.to_csv('Injury_Number_by_Type_Sex_Age_1999_2008.csv',index=None)
