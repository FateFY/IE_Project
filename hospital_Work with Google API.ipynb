# %%
import pandas as pd
import googlemaps

# %%
gmap_key = googlemaps.Client(key = 'AIzaSyDbtU1r9nDkNjvRzpQE2r2spqDqEpcphyY')

# %%
hos = pd.read_csv('new_hospital_data.csv')

# %%
hos.head()
# Out:
#                                      Name   Sector              Address  \
# 0                      Albert Road Clinic  Private       31 Albert Road
# 1  Albury Wodonga Health [Wodonga Campus]   Public    69 Vermont Street
# 2             Alexandra District Hospital   Public     12 Cooper Street
# 3                  Alpine Health [Bright]   Public  36-42 Cobden Street
# 4            Alpine Health [Mount Beauty]   Public   10 Hollonds Street
#
#       Suburb State  Postcode   Latitude   Longitude         Phone  \
# 0  Melbourne   VIC      3004 -37.834246  144.972151  03 9256 8311
# 1    Wodonga   VIC      3690 -36.131791  146.879417  02 6051 7111
# 2  Alexandra   VIC      3714 -37.195065  145.716143  03 5772 0900
# 3     Bright   VIC      3741 -36.732701  146.965924  03 5755 0100
# 4  Mt Beauty   VIC      3699 -36.743354  147.169359  03 5754 3500
#
#                         Website                                    Services  \
# ...

# %%
gmap_key.find_place('Albury Wodonga Health [Wodonga Campus]',input_type = 'textquery')['candidates'][0]['place_id']
# Out:
# 'ChIJydqlD_9YIWsRCYWnujeiaec'

# %%
gmap_key.place('ChIJydqlD_9YIWsRCYWnujeiaec').keys()
# Out:
# dict_keys(['html_attributions', 'result', 'status'])

# %%
gmap_key.place('ChIJydqlD_9YIWsRCYWnujeiaec')['result']
# Out:
# {'address_components': [{'long_name': '53-81',
#    'short_name': '53-81',
#    'types': ['street_number']},
#   {'long_name': 'Vermont Street',
#    'short_name': 'Vermont St',
#    'types': ['route']},
#   {'long_name': 'Wodonga',
#    'short_name': 'Wodonga',
#    'types': ['locality', 'political']},
#   {'long_name': 'Wodonga City',
#    'short_name': 'Wodonga',
#    'types': ['administrative_area_level_2', 'political']},
#   {'long_name': 'Victoria',
#    'short_name': 'VIC',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'Australia',
#    'short_name': 'AU',
#    'types': ['country', 'political']},
#   {'long_name': '3690', 'short_name': '3690', 'types': ['postal_code']}],
#  'adr_address': '<span class="street-address">53-81 Vermont St</span>, <span class="locality">Wodonga</span> <span class="region">VIC</span> <span class="postal-code">3690</span>, <span class="country-name">Australia</span>',
# ...

# %%
hos['Monday_Start_Time'] = None
hos['Monday_End_Time'] = None
hos['Tuesday_Start_Time'] = None
hos['Tuesday_End_Time'] = None
hos['Wednesday_Start_Time'] = None
hos['Wednesday_End_Time'] = None
hos['Thursday_Start_Time'] = None
hos['Thursday_End_Time'] = None
hos['Friday_Start_Time'] = None
hos['Friday_End_Time'] = None
hos['Saturday_Start_Time'] = None
hos['Saturday_End_Time'] = None
hos['Sunday_Start_Time'] = None
hos['Sunday_End_Time'] = None
hos['Weekday_Opening_Hour'] = None

# %%
hos.columns.get_loc('Monday_Start_Time')
# Out:
# 19

# %%
hos.columns.get_loc('Sunday_End_Time')
# Out:
# 32

# %%
hos.head()
# Out:
#                                      Name   Sector              Address  \
# 0                      Albert Road Clinic  Private       31 Albert Road
# 1  Albury Wodonga Health [Wodonga Campus]   Public    69 Vermont Street
# 2             Alexandra District Hospital   Public     12 Cooper Street
# 3                  Alpine Health [Bright]   Public  36-42 Cobden Street
# 4            Alpine Health [Mount Beauty]   Public   10 Hollonds Street
#
#       Suburb State  Postcode   Latitude   Longitude         Phone  \
# 0  Melbourne   VIC      3004 -37.834246  144.972151  03 9256 8311
# 1    Wodonga   VIC      3690 -36.131791  146.879417  02 6051 7111
# 2  Alexandra   VIC      3714 -37.195065  145.716143  03 5772 0900
# 3     Bright   VIC      3741 -36.732701  146.965924  03 5755 0100
# 4  Mt Beauty   VIC      3699 -36.743354  147.169359  03 5754 3500
#
#                         Website  \
# 0  www.albertroadclinic.com.au/
# 1                           NaN
# ...

# %%
rebuild_one = []
for i in range(hos.shape[0]):
    try:
        temp = gmap_key.find_place(hos.iloc[i,0],input_type = 'textquery')
        ids = temp['candidates'][0]['place_id']
        fac = gmap_key.place(ids)
        if 'opening_hours' in fac['result'].keys():
            if 'weekday_text' in fac['result']['opening_hours'].keys():
                opening = "\n".join(fac['result']['opening_hours']['weekday_text'])
                hos.iloc[i,hos.columns.get_loc('Weekday_Opening_Hour')] = opening
            if 'periods' in fac['result']['opening_hours'].keys():
                weekdays = fac['result']['opening_hours']['periods']
                for each in range(len(weekdays)):
                    hos.iloc[i,2*each+19] = weekdays[each]['open']['time']
                    hos.iloc[i,2*each+20] = weekdays[each]['close']['time']
    except:
        rebuild_one.append(i)
    if i%50==0:
        print('Tik-tok',i)
# Out:
# Tik-tok 0
# Tik-tok 50
# Tik-tok 100
# Tik-tok 150
# Tik-tok 200
# Tik-tok 250

# %%
rebuild_one
# Out:
# [1,
#  2,
#  4,
#  6,
#  7,
#  8,
#  10,
#  12,
#  17,
#  18,
#  22,
#  25,
#  28,
#  32,
#  34,
#  35,
#  37,
#  41,
#  48,
#  51,
#  53,
#  61,
#  72,
#  73,
#  74,
#  75,
#  76,
#  80,
#  82,
#  86,
#  89,
#  95,
#  102,
#  104,
#  105,
#  106,
#  109,
#  113,
#  117,
#  120,
#  121,
#  124,
#  127,
#  130,
#  131,
#  132,
#  137,
#  138,
#  143,
#  144,
#  148,
#  151,
#  153,
#  154,
#  157,
#  158,
#  160,
#  164,
#  165,
#  166,
#  168,
#  170,
#  172,
#  175,
#  176,
#  177,
#  178,
#  179,
#  181,
#  183,
#  185,
#  186,
#  187,
#  188,
#  189,
#  190,
#  193,
#  195,
#  197,
#  198,
#  199,
#  201,
#  203,
#  205,
#  215,
#  216,
#  217,
#  218,
#  224,
#  225,
#  228,
#  231,
#  233,
#  236,
#  248,
#  249,
#  250,
#  251,
#  252,
#  255,
#  257,
#  263,
#  268,
#  269,
#  275]

# %%
hos[hos.Weekday_Opening_Hour.isnull() == True].shape
# Out:
# (74, 34)

# %%
hos.columns
# Out:
# Index(['Name', 'Sector', 'Address', 'Suburb', 'State', 'Postcode', 'Latitude',
#        'Longitude', 'Phone', 'Website', 'Services', 'Beds', 'Description',
#        'Emergency_Flag', 'Resuscitation_Percent_seen_on_time',
#        'Emergency_Percent_seen_on_time', 'Urgent_Percent_seen_on_time',
#        'Semi_Urgent_Percent_seen_on_time', 'Non_Urgent_Percent_seen_on_time',
#        'Monday_Start_Time', 'Monday_End_Time', 'Tuesday_Start_Time',
#        'Tuesday_End_Time', 'Wednesday_Start_Time', 'Wednesday_End_Time',
#        'Thursday_Start_Time', 'Thursday_End_Time', 'Friday_Start_Time',
#        'Friday_End_Time', 'Saturday_Start_Time', 'Saturday_End_Time',
#        'Sunday_Start_Time', 'Sunday_End_Time', 'Weekday_Opening_Hour'],
#       dtype='object')

# %%
hos = hos[['Name', 'Address', 'Suburb', 'State', 'Postcode', 'Latitude',
       'Longitude','Sector',  'Phone', 'Website', 'Beds','Services', 'Weekday_Opening_Hour', 'Description',
       'Emergency_Flag', 'Resuscitation_Percent_seen_on_time',
       'Emergency_Percent_seen_on_time', 'Urgent_Percent_seen_on_time',
       'Semi_Urgent_Percent_seen_on_time', 'Non_Urgent_Percent_seen_on_time']]

# %%
hos.to_csv('Hospital_Data.csv',index = False)
